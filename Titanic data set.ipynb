# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#to load csv file
df=pd.read_csv(r"C:\Users\guddi\Desktop\documents\train-200907-141856.csv")

# %%
#print header of csv file
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#print dimensional size of dataset
df.shape
# Out:
# (891, 12)

# %%
#print name of variables or feature
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#print type of variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#print descriptive statistic of numeric variables
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#print descriptive statistic of non numeric variables
df.describe(include='object')
# Out:
#                       Name   Sex Ticket    Cabin Embarked
# count                  891   891    891      204      889
# unique                 891     2    681      147        3
# top     Moor, Mrs. (Beila)  male   1601  B96 B98        S
# freq                     1   577      7        4      644

# %%
#print counts of distinct values for categorical variables
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#print percentage of distinct values for categorical variables
df['Sex'].value_counts(normalize='True')
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
#projecting one column
#project name and apply head()
df['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
#project age and apply max()
df['Age'].max()
# Out:
# 80.0

# %%
#project age and apply min()
df['Age'].min()
# Out:
# 0.42

# %%
#project age and apply mean()
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
#project sex and apply value counts()
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#projecting columns and rows with iloc[] and loc[] methods
df.loc[0:15,'Name']
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %%
df.loc[0:15,'Name':'Embarked']
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
df.iloc[0:15,0:4]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# ...

# %%
#print name of the oldest passenger travelling on ship
df[df['Age']==df[df['Sex']=='male']['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
#sorting
df.sort_values(by=['Name','Age'],ascending=[True,False]).head()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
#
#         Sex   Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845    male  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746    male  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  female  35.0      1      1  C.A. 2673  20.25   NaN        S
# 308    male  30.0      1      0  P/PP 3381  24.00   NaN        C
# 874  female  28.0      1      0  P/PP 3381  24.00   NaN        C

# %%
df.sort_values(by='Age',ascending=True).head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
df.sort_values(by=['Name','Age'],ascending=[True,False])
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#replacing value in column through map()method
d={'male':0,'female':1}
df['Sex']=df['Sex'].map(d)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#replacing value in column through replace method
o={0:'male',1:'female'}
df=df.replace({'Sex:o'})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#describe age of persons grouped by survived attribute
df.groupby(by='Survived')['Age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# Survived
# 0         424.0  30.626179  14.172110  1.00  21.0  28.0  39.0  74.0
# 1         290.0  28.343690  14.950952  0.42  19.0  28.0  36.0  80.0

# %%
#relating 2 variables
pd.crosstab(df['Sex'],df['Survived'],normalize=True)
# Out:
# Survived         0         1
# Sex
# 0         0.525253  0.122334
# 1         0.090909  0.261504

# %%
df.pivot_table(['Age','Fare'],['Survived'],aggfunc='mean')
# Out:
#                 Age       Fare
# Survived
# 0         30.626179  22.117887
# 1         28.343690  48.395408

# %%
config InlineBackend.figure_format='retina'

# %%
#bargraph
sns.countplot(x='Survived',data=df)

# %%
sns.countplot(x='Survived',hue='Sex',data=df)

# %%
#linechart
sns.lineplot(x='Age',y='Fare',data=df)

# %%
#scatterplot
df.plot.scatter(x='Age',y='Fare')

# %%
df.plot.scatter(x='Age',y='Survived')

# %%
#histogram
df['Age'].hist(bins=8)

# %%
#piechart
sizes=df['Survived'].value_counts()
fig1,ax1=plt.subplots()
ax1.pie(sizes,labels=['Not Survived','Survived'],autopct='%1.1f%%',shadow=True)
plt.show()
